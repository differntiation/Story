# %% [markdown]
# <a href="https://colab.research.google.com/github/differntiation/Story/blob/master/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library :-Useful for data processing ans Analysis
# ---
# Pandas Data Frame:-It is 2-d tabular data structure with labelled axes(rows and column)

# %%
#importing pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# creating pandas dataframe

# %%
#importing csv file to pandas dataframe
boston_df=pd.read_csv('/content/boston.csv')
type(boston_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#print 5 rows of boston dataframe
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %% [markdown]
#  Loading the Data from excel to a pandas dataframe
#
# *   pd.read_excel(file_path)
#
#
# * Exporting dataframe to csv file

# %%
boston_df.to_csv('pagal.csv') # Here we have change dataframe to csv file and named it pagal

# %% [markdown]
# Exporting pandas dataframe to excel
#
# *   df.to_excel(filename)

# %%
#creating a dataframe with random values
random_df=pd.DataFrame(np.random.rand(20,10))  #it create 20 rows and 10 col with random number

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.022484  0.921204  0.922307  0.369429  0.037275  0.919396  0.087549
# 1  0.613984  0.037825  0.690979  0.917930  0.864006  0.469086  0.253481
# 2  0.277282  0.664267  0.809431  0.025092  0.576798  0.831176  0.643946
# 3  0.034893  0.556521  0.242589  0.802199  0.213566  0.228964  0.014470
# 4  0.550099  0.637297  0.342499  0.638932  0.657730  0.010271  0.556420
#
#           7         8         9
# 0  0.359506  0.073818  0.759233
# 1  0.621160  0.302048  0.799040
# 2  0.405660  0.792814  0.718174
# 3  0.188327  0.469996  0.974912
# 4  0.764048  0.554578  0.433403

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# Inspecting the DataFrame

# %%
boston_df.shape # gives idea about row and col
# Out:
# (506, 15)

# %%
#print first 5 rows of boston dataframe
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %%
#print last 5 rows of boston dataframe
boston_df.tail()
# Out:
#      Unnamed: 0     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 501         501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO       B  LSTAT  PRICE
# 501  273.0     21.0  391.99   9.67   22.4
# 502  273.0     21.0  396.90   9.08   20.6
# 503  273.0     21.0  396.90   5.64   23.9
# 504  273.0     21.0  393.45   6.48   22.0
# 505  273.0     21.0  396.90   7.88   11.9

# %%
#information anout dataframe
boston_df.info()  #here 506 non-null means no any data is missing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  B           506 non-null    float64
#  13  LSTAT       506 non-null    float64
#  14  PRICE       506 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 59.4 KB

# %%
#finding the number of missing value in each col
boston_df.isnull().sum()
# Out:
# Unnamed: 0    0
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# B             0
# LSTAT         0
# PRICE         0
# dtype: int64

# %%
diabetes_df=pd.read_csv('/content/diabetes.csv')

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on the labels
diabetes_df.value_counts('Outcome')  # here 0-> no diabetes means 500 has no diabetes
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#Group the values based on mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical Measure

# %%
#count number of values in each col
boston_df.count()
# Out:
# Unnamed: 0    506
# CRIM          506
# ZN            506
# INDUS         506
# CHAS          506
# NOX           506
# RM            506
# AGE           506
# DIS           506
# RAD           506
# TAX           506
# PTRATIO       506
# B             506
# LSTAT         506
# PRICE         506
# dtype: int64

# %%
#mean value ->column wise
boston_df.mean()
# Out:
# Unnamed: 0    252.500000
# CRIM            3.613524
# ZN             11.363636
# INDUS          11.136779
# CHAS            0.069170
# NOX             0.554695
# RM              6.284634
# AGE            68.574901
# DIS             3.795043
# RAD             9.549407
# TAX           408.237154
# PTRATIO        18.455534
# B             356.674032
# LSTAT          12.653063
# PRICE          22.532806
# dtype: float64

# %%
# standard deviation  value ->column wise
boston_df.std()
# Out:
# Unnamed: 0    146.213884
# CRIM            8.601545
# ZN             23.322453
# INDUS           6.860353
# CHAS            0.253994
# NOX             0.115878
# RM              0.702617
# AGE            28.148861
# DIS             2.105710
# RAD             8.707259
# TAX           168.537116
# PTRATIO         2.164946
# B              91.294864
# LSTAT           7.141062
# PRICE           9.197104
# dtype: float64

# %%
# min value in each col
boston_df.min()
# Out:
# Unnamed: 0      0.00000
# CRIM            0.00632
# ZN              0.00000
# INDUS           0.46000
# CHAS            0.00000
# NOX             0.38500
# RM              3.56100
# AGE             2.90000
# DIS             1.12960
# RAD             1.00000
# TAX           187.00000
# PTRATIO        12.60000
# B               0.32000
# LSTAT           1.73000
# PRICE           5.00000
# dtype: float64

# %%
#max value in each col
boston_df.min()
# Out:
# Unnamed: 0      0.00000
# CRIM            0.00632
# ZN              0.00000
# INDUS           0.46000
# CHAS            0.00000
# NOX             0.38500
# RM              3.56100
# AGE             2.90000
# DIS             1.12960
# RAD             1.00000
# TAX           187.00000
# PTRATIO        12.60000
# B               0.32000
# LSTAT           1.73000
# PRICE           5.00000
# dtype: float64

# %%
# All statistical measure in one go
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %% [markdown]
# Manipulating a dataframe

# %%
# Adding col 'No. of police station' in boston  dataFrame which is same as Outcome col of diabetes_df
boston_df['No. of police station']=diabetes_df.Outcome

# %%
boston_df.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE  No. of police station
# 0  296.0     15.3  396.90   4.98   24.0                      1
# 1  242.0     17.8  396.90   9.14   21.6                      0
# 2  242.0     17.8  392.83   4.03   34.7                      1
# 3  222.0     18.7  394.63   2.94   33.4                      0
# 4  222.0     18.7  396.90   5.33   36.2                      1

# %%
#Removing a particular row temporarily
boston_df.drop(index=0,axis=0)  # if you remove all col of row=0 then axis=0

#if you want to remove permanently then store in particular df
#  boston_df2=boston_df.drop(index=0,axis=0)  and now call boston_df2
# Out:
#      Unnamed: 0     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 1             1  0.02731  0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729  0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237  0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905  0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# 5             5  0.02985  0.0   2.18   0.0  0.458  6.430  58.7  6.0622  3.0
# ..          ...      ...  ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
# ...

# %%
#drop a "ZN" col
boston_df.drop(columns='ZN', axis=1)
# Out:
#      Unnamed: 0     CRIM  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0             0  0.00632   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1             1  0.02731   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2             2  0.02729   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3             3  0.03237   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4             4  0.06905   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..          ...      ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501         501  0.06263  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502         502  0.04527  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503         503  0.06076  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504         504  0.10959  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505         505  0.04741  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
# ...

# %%
#locate particular rows using index VALUE
boston_df.iloc[2]
# Out:
# Unnamed: 0                 2.00000
# CRIM                       0.02729
# ZN                         0.00000
# INDUS                      7.07000
# CHAS                       0.00000
# NOX                        0.46900
# RM                         7.18500
# AGE                       61.10000
# DIS                        4.96710
# RAD                        2.00000
# TAX                      242.00000
# PTRATIO                   17.80000
# B                        392.83000
# LSTAT                      4.03000
# PRICE                     34.70000
# No. of police station      1.00000
# Name: 2, dtype: float64

# %%
#locating a particular col
print(boston_df.iloc[:,0])  # first col is print
print(boston_df.iloc[:,1])
print(boston_df.iloc[:,-1]) #print last col
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 501    501
# 502    502
# 503    503
# 504    504
# 505    505
# Name: Unnamed: 0, Length: 506, dtype: int64
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 501    0
# 502    1
# 503    0
# 504    0
# 505    0
# Name: No. of police station, Length: 506, dtype: int64

# %% [markdown]
# Correlation :-Find the relationship between the various col
#
#
# 1.   positive correlation ex:no.of rooms and house price
# 2.   negative correlation ex:-crime rate and price is negatively correlated

# %%
boston_df.corr()
# Out:
#                        Unnamed: 0      CRIM        ZN     INDUS      CHAS  \
# Unnamed: 0               1.000000  0.407407 -0.103393  0.399439 -0.003759
# CRIM                     0.407407  1.000000 -0.200469  0.406583 -0.055892
# ZN                      -0.103393 -0.200469  1.000000 -0.533828 -0.042697
# INDUS                    0.399439  0.406583 -0.533828  1.000000  0.062938
# CHAS                    -0.003759 -0.055892 -0.042697  0.062938  1.000000
# NOX                      0.398736  0.420972 -0.516604  0.763651  0.091203
# RM                      -0.079971 -0.219247  0.311991 -0.391676  0.091251
# AGE                      0.203784  0.352734 -0.569537  0.644779  0.086518
# DIS                     -0.302211 -0.379670  0.664408 -0.708027 -0.099176
# RAD                      0.686002  0.625505 -0.311948  0.595129 -0.007368
# TAX                      0.666626  0.582764 -0.314563  0.720760 -0.035587
# PTRATIO                  0.291074  0.289946 -0.391679  0.383248 -0.121515
# ...
